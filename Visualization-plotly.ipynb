# %%
import pandas as pd
df = pd.read_csv('data/winequality-red.csv', delimiter=';')

# %%
# Revisit the data to see what it looks like. 
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import chart_studio.plotly as py
import plotly.graph_objects as go
#fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
#fig.show()

# %%
# Let's try a histogram first. 
data = go.Histogram(x=df['quality'])
layout = go.Layout()
fig = go.Figure(data = data)
fig.show()
# Out:
# <div>
#
#
#             <div id="099c03bc-b278-4971-aece-f412a7d2aff3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("099c03bc-b278-4971-aece-f412a7d2aff3")) {
#                     Plotly.newPlot(
#                         '099c03bc-b278-4971-aece-f412a7d2aff3',
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# This will not work. Any guesses why? - Because we need to specify x and y data
# df.plot(kind='scatter') - This will not work
data = go.Scatter(x=df['fixed acidity'], y=df['alcohol'], mode='markers')
layout = go.Layout(height=600)
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="826c8385-6ae3-4b13-89db-536496315e1f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("826c8385-6ae3-4b13-89db-536496315e1f")) {
#                     Plotly.newPlot(
#                         '826c8385-6ae3-4b13-89db-536496315e1f',
# ...

# %%
# As you might guess from the error, we have to specify X and Y columns for Pandas to plot. 

data = go.Scatter(x=df['free sulfur dioxide'], y=df['total sulfur dioxide'], mode='markers', )
layout = go.Layout(height=600, showlegend=True)
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="80157cea-ea59-4b95-8fb1-e3a1102dd5d4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80157cea-ea59-4b95-8fb1-e3a1102dd5d4")) {
#                     Plotly.newPlot(
#                         '80157cea-ea59-4b95-8fb1-e3a1102dd5d4',
# ...

# %%
# We don't need to specify a column necessarily, but because of the different scales this 
# doesn't look too great. Let's specify three columns and see how that looks...
total sulfur dioxide

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# This still doesn't look great - it's hard to really examine these three columns since pH is 
# so different from the other two. Let's drop pH and try one more time...
#import plotly.express as px
fig = go.Figure()
fig.add_trace(go.Box(y=df['fixed acidity'], name='Fixed acidity', opacity=0.5))
fig.add_trace(go.Box(y=df['pH'], name='pH', opacity=0.5))
fig.show()

#['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
# Out:
# <div>
#
#
#             <div id="4c1aa34b-926a-4d17-8b6a-e8a10adcda23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c1aa34b-926a-4d17-8b6a-e8a10adcda23")) {
#                     Plotly.newPlot(
#                         '4c1aa34b-926a-4d17-8b6a-e8a10adcda23',
# ...

# %% [markdown]
# ##### Plotting Questions
#
# 1. Create a `scatterplot` between two variables of your choosing.
# 2. Create a `barplot` between one to three variables of your choosing.

# %%
# Q1 
#df.columns
data = go.Scatter(x=df['residual sugar'], y=df['alcohol'], mode='markers')
layout = go.Layout()

fig.update_xaxes(title_text='residual sugar')
fig.update_yaxes(title_text='alcohol')

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="a3437513-015e-4bb2-b1a2-924166878ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a3437513-015e-4bb2-b1a2-924166878ce0")) {
#                     Plotly.newPlot(
#                         'a3437513-015e-4bb2-b1a2-924166878ce0',
# ...

# %%
# Q2
df[['density', 'sulphates']].plot(kind='box')
